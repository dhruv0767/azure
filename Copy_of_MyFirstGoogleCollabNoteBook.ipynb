# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruv0767/azure/blob/main/Copy_of_MyFirstGoogleCollabNoteBook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Wed Dec 15 09:24:55 2021

# %%
import time
print(time.ctime())
# Out:
# Wed Dec 15 09:25:30 2021
